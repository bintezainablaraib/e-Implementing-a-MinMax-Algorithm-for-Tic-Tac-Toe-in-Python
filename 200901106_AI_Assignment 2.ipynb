# %% [markdown]
# import random
#
# def board_layout(): return \[\[‘-’, ‘-’, ‘-’\], \[‘-’, ‘-’, ‘-’\],
# \[‘-’, ‘-’, ‘-’\]\]
#
# def print_board(board): for row in board: print(’ ’.join(row)) print()
#
# def simulation(): board = board_layout() print_board(board)
# current_player = ‘X’ game_winner = None while not game_winner and not
# is_board_full(board): if current_player == ‘X’: user_turn(board) else:
# system_move(board) print_board(board) game_winner = check_winner(board)
# current_player = get_next_player(current_player)
# result_print(game_winner)
#
# def get_next_player(current_player): return ‘X’ if current_player == ‘O’
# else ‘O’
#
# def user_turn(board): row, col = input_user() while not make_move(board,
# ‘X’, row, col): print(“That space is already taken. Try again.”) row,
# col = input_user()
#
# def input_user(): row = int(input(“Enter row number (0-2):”)) col =
# int(input(“Enter column number (0-2):”)) return row, col
#
# def make_move(board, player, row, col): if board\[row\]\[col\] == ‘-’:
# board\[row\]\[col\] = player return True else: return False
#
# def system_move(board): free_spaces = free_space(board) if free_spaces:
# row, col = random.choice(free_spaces) make_move(board, ‘O’, row, col)
#
# def free_space(board): free_spaces = \[\] for i in range(3): for j in
# range(3): if board\[i\]\[j\] == ‘-’: free_spaces.append((i, j)) return
# free_spaces
#
# def check_winner(board): for player in \[‘X’, ‘O’\]: for i in range(3):
# \# Check rows, columns, and diagonals if (board\[i\] == \[player\] \* 3
# or \[board\[j\]\[i\] for j in range(3)\] == \[player\] \* 3 or
# \[board\[j\]\[j\] for j in range(3)\] == \[player\] \* 3 or
# \[board\[j\]\[2-j\] for j in range(3)\] == \[player\] \* 3): return
# player return None
#
# def is_board_full(board): return not any(‘-’ in row for row in board)
#
# def result_print(game_winner): if game_winner: print(f”{game_winner}
# wins!“) else: print(”Draw!“)
#
# simulation()
